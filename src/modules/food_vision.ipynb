# %% [markdown]
# # FoodVision

# %%
from common import CV_DATASETS_DIR

# %%
DATASET_PATH = CV_DATASETS_DIR/"food"/"pizza_steak_sushi"

# %%
# %run food_vision/food_vision.py --data_dir={DATASET_PATH}
